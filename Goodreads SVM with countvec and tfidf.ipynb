# %%
import json
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
import datetime

# start time
start_time = datetime.datetime.now()

# load the reviews from the JSON file into a Pandas DataFrame
reviews = []
with open('goodreads_reviews_young_adult.json', 'r') as f:
    for line in f:
        review = json.loads(line)
        reviews.append((review['review_text'], review['rating']))
df = pd.DataFrame(reviews, columns=['text', 'rating'])

# define a function to map ratings to sentiment labels
def map_rating_to_sentiment(rating):
    if rating >= 3:
        return 'positive'
    else:
        return 'negative'

# map the ratings to sentiment labels
df['sentiment'] = df['rating'].apply(map_rating_to_sentiment)

# split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(df['text'], df['sentiment'], test_size=0.2, random_state=42)

# vectorize the text data using a bag-of-words model
vectorizer = CountVectorizer(stop_words='english')
X_train_vec = vectorizer.fit_transform(X_train)
X_test_vec = vectorizer.transform(X_test)

# train an SVM classifier on the training data
clf = SVC(kernel='linear', C=1.0, random_state=42)
clf.fit(X_train_vec, y_train)

# evaluate the performance of the classifier on the testing data
accuracy = clf.score(X_test_vec, y_test)
print("Accuracy of the classifier on the testing set: {:.2f}%".format(accuracy * 100))

# end time
end_time = datetime.datetime.now()

# total time
delta_time = end_time - start_time
print(f"Elapsed time: {delta_time.total_seconds()} seconds")

# %%
import json
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
import datetime

# start time
start_time = datetime.datetime.now()

# load the reviews from the JSON file into a Pandas DataFrame
reviews = []
with open('goodreads_reviews_young_adult.json', 'r') as f:
    for line in f:
        # Keep only 1/4 of the data
        if hash(line) % 4 == 0:
            review = json.loads(line)
            reviews.append((review['review_text'], review['rating']))
df = pd.DataFrame(reviews, columns=['text', 'rating'])

# define a function to map ratings to sentiment labels
def map_rating_to_sentiment(rating):
    if rating >= 3:
        return 'positive'
    else:
        return 'negative'

# map the ratings to sentiment labels
df['sentiment'] = df['rating'].apply(map_rating_to_sentiment)

# split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(df['text'], df['sentiment'], test_size=0.2, random_state=42)

# vectorize the text data using a bag-of-words model
vectorizer = CountVectorizer(stop_words='english')
X_train_vec = vectorizer.fit_transform(X_train)
X_test_vec = vectorizer.transform(X_test)

# train an SVM classifier on the training data
clf = SVC(kernel='linear', C=1.0, random_state=42)
clf.fit(X_train_vec, y_train)

# evaluate the performance of the classifier on the testing data
accuracy = clf.score(X_test_vec, y_test)
print("Accuracy of the classifier on the testing set: {:.2f}%".format(accuracy * 100))

# end time
end_time = datetime.datetime.now()

# total time
delta_time = end_time - start_time
print(f"Elapsed time: {delta_time.total_seconds()} seconds")

# %%
import json
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
import datetime

# start time
start_time = datetime.datetime.now()

# load the reviews from the JSON file into a Pandas DataFrame
reviews = []
with open('goodreads_reviews_young_adult.json', 'r') as f:
    for line in f:
        # Keep only 1/4 of the data
        if hash(line) % 100 == 0:
            review = json.loads(line)
            reviews.append((review['review_text'], review['rating']))
df = pd.DataFrame(reviews, columns=['text', 'rating'])

# define a function to map ratings to sentiment labels
def map_rating_to_sentiment(rating):
    if rating >= 3:
        return 'positive'
    else:
        return 'negative'

# map the ratings to sentiment labels
df['sentiment'] = df['rating'].apply(map_rating_to_sentiment)

# split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(df['text'], df['sentiment'], test_size=0.2, random_state=42)

# vectorize the text data using a bag-of-words model
vectorizer = CountVectorizer(stop_words='english')
X_train_vec = vectorizer.fit_transform(X_train)
X_test_vec = vectorizer.transform(X_test)

# train an SVM classifier on the training data
clf = SVC(kernel='linear', C=1.0, random_state=42)
clf.fit(X_train_vec, y_train)

# evaluate the performance of the classifier on the testing data
accuracy = clf.score(X_test_vec, y_test)
print("Accuracy of the classifier on the testing set: {:.2f}%".format(accuracy * 100))

# end time
end_time = datetime.datetime.now()

# total time
delta_time = end_time - start_time
print(f"Elapsed time: {delta_time.total_seconds()} seconds")

# %%
import json
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
import datetime

# start time
start_time = datetime.datetime.now()

# load the reviews from the JSON file into a Pandas DataFrame
reviews = []
with open('goodreads_reviews_young_adult.json', 'r') as f:
    for line in f:
        if hash(line) % 1000 == 0:
            review = json.loads(line)
            reviews.append((review['review_text'], review['rating']))
df = pd.DataFrame(reviews, columns=['text', 'rating'])

# define a function to map ratings to sentiment labels
def map_rating_to_sentiment(rating):
    if rating >= 3:
        return 'positive'
    else:
        return 'negative'

# map the ratings to sentiment labels
df['sentiment'] = df['rating'].apply(map_rating_to_sentiment)

# split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(df['text'], df['sentiment'], test_size=0.2, random_state=42)

# vectorize the text data using a bag-of-words model
vectorizer = CountVectorizer(stop_words='english')
X_train_vec = vectorizer.fit_transform(X_train)
X_test_vec = vectorizer.transform(X_test)

# train an SVM classifier on the training data
clf = SVC(kernel='linear', C=1.0, random_state=42)
clf.fit(X_train_vec, y_train)

# evaluate the performance of the classifier on the testing data
accuracy = clf.score(X_test_vec, y_test)
print("Accuracy of the classifier on the testing set: {:.2f}%".format(accuracy * 100))

# end time
end_time = datetime.datetime.now()

# total time
delta_time = end_time - start_time
print(f"Elapsed time: {delta_time.total_seconds()} seconds")

# %%
import json
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
import datetime

# %%
# start time
start_time = datetime.datetime.now()

# load the reviews from the JSON file into a Pandas DataFrame
reviews = []
with open('goodreads_reviews_young_adult.json', 'r') as f:
    for line in f:
        if hash(line) % 1000 == 0:
            review = json.loads(line)
            reviews.append((review['review_text'], review['rating']))
df = pd.DataFrame(reviews, columns=['text', 'rating'])

# %%
# define a function to map ratings to sentiment labels
def map_rating_to_sentiment(rating):
    if rating >= 3:
        return 'positive'
    else:
        return 'negative'

# map the ratings to sentiment labels
df['sentiment'] = df['rating'].apply(map_rating_to_sentiment)

# %%
# split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(df['text'], df['sentiment'], test_size=0.2, random_state=42)

# %%
# vectorize the text data using a bag-of-words model
vectorizer = CountVectorizer(stop_words='english')
X_train_vec = vectorizer.fit_transform(X_train)
X_test_vec = vectorizer.transform(X_test)

# %%
# train an SVM classifier on the training data
clf = SVC(kernel='linear', C=1.0, random_state=42)
# change linear to "gausian" or any other kernel, which could make it worse or better. overfit/underfit. test it!
clf.fit(X_train_vec, y_train)
# Out:
# SVC(kernel='linear', random_state=42)

# %%
# evaluate the performance of the classifier on the testing data
accuracy = clf.score(X_test_vec, y_test)
print("Accuracy of the classifier on the testing set: {:.2f}%".format(accuracy * 100))
# Out:
# Accuracy of the classifier on the testing set: 84.00%

# %%
print(X_train_vec[:2])
# Out:
#   (0, 10431)	2
#   (0, 12287)	1
#   (0, 17227)	1
#   (0, 16654)	1
#   (0, 3101)	1
#   (0, 15331)	1
#   (0, 5936)	1
#   (0, 2146)	1
#   (0, 773)	1
#   (0, 17680)	1
#   (0, 4162)	1
#   (1, 10431)	1
#   (1, 7333)	1
#   (1, 16709)	1
#   (1, 15752)	1
#   (1, 4027)	3
#   (1, 9050)	1
#   (1, 3192)	1
#   (1, 6884)	1
#   (1, 15029)	1
#   (1, 19573)	1
#   (1, 9924)	1
#   (1, 17918)	1
#   (1, 8076)	1
#   (1, 15699)	1
#   :	:
#   (1, 10214)	1
#   (1, 5463)	1
#   (1, 10635)	1
#   (1, 2886)	2
#   (1, 14555)	1
#   (1, 17123)	1
#   (1, 542)	1
#   (1, 3328)	1
#   (1, 9234)	1
#   (1, 19042)	1
#   (1, 13007)	1
#   (1, 5069)	1
#   (1, 1739)	1
#   (1, 10186)	1
#   (1, 17139)	1
#   (1, 8117)	1
#   (1, 18101)	1
#   (1, 12434)	1
#   (1, 17218)	1
#   (1, 17652)	1
#   (1, 14956)	1
#   (1, 17801)	1
#   (1, 17461)	1
#   (1, 19282)	1
#   (1, 7837)	1

# %%
vectorizer.vocabulary_
# Out:
# {'love': 10431,
#  'oh': 12287,
#  'swoon': 17227,
#  'st': 16654,
#  'clair': 3101,
#  'say': 15331,
#  'etienne': 5936,
#  'book': 2146,
#  'amazing': 773,
#  'thing': 17680,
#  'day': 4162,
#  'good': 7333,
#  'start': 16709,
#  'series': 15752,
#  'cyra': 4027,
#  'jackson': 9050,
#  'closer': 3192,
#  'friends': 6884,
#  'romantic': 15029,
#  'youth': 19573,
#  'laws': 9924,
#  'torn': 17918,
#  'home': 8076,
#  'sent': 15699,
#  'eden': 5306,
#  'just': 9295,
#  'gilded': 7218,
#  'cage': 2516,
#  'heaven': 7860,
#  'hoping': 8121,
#  'story': 16836,
#  'bit': 1972,
#  'slow': 16254,
#  'times': 17794,
#  'background': 1525,
#  'like': 10184,
#  'linc': 10214,
#  'ellie': 5463,
#  'make': 10635,
#  'characters': 2886,
#  'relatable': 14555,
#  'surprises': 17123,
#  'agree': 542,
#  'comment': 3328,
#  'journey': 9234,
#  'wall': 19042,
#  'perilous': 13007,
#  'dramatic': 5069,
#  'begun': 1739,
#  'liked': 10186,
#  'survived': 17139,
#  'hopefully': 8117,
#  'triangle': 18101,
#  'ordinary': 12434,
#  'swinging': 17218,
#  'theo': 17652,
#  'risked': 14956,
#  'tine': 17801,
#  'tell': 17461,
#  'win': 19282,
#  'heart': 7837,
#  'best': 1874,
#  'going': 7320,
#  'tris': 18129,
#  'tobias': 17850,
#  'point': 13333,
#  'view': 18860,
#  'couldn': 3744,
#  'apart': 1002,
#  'parts': 12758,
#  'plot': 13283,
#  'didn': 4638,
#  'line': 10221,
#  'clearly': 3150,
#  'ending': 5608,
#  'read': 14285,
#  'happens': 7702,
#  'pleased': 13269,
#  'quite': 14120,
#  'exciting': 6035,
#  'somewhat': 16412,
#  'predictable': 13558,
#  'honestly': 8095,
#  'better': 1892,
#  'felt': 6415,
#  'way': 19115,
#  'possibly': 13451,
#  'ended': 5602,
#  'really': 14332,
#  'enjoyed': 5648,
#  'entire': 5695,
#  'fun': 6947,
#  'version': 18800,
#  'enders': 5605,
#  'game': 7009,
#  'jeg': 9121,
#  'havde': 7782,
#  'sadan': 15192,
#  'glaedet': 7263,
#  'mig': 11235,
#  'til': 17782,
#  'laese': 9818,
#  'videre': 18849,
#  'denne': 4396,
#  'trilogi': 18120,
#  'da': 4030,
#  'virkelig': 18890,
#  'forguder': 6758,
#  'ally': 707,
#  'condies': 3476,
#  'skrivestil': 16192,
#  'synes': 17255,
#  'hun': 8230,
#  'skriver': 16191,
#  'sa': 15170,
#  'fantastisk': 6292,
#  'og': 12284,
#  'kommer': 9708,
#  'en': 5551,
#  'meget': 10931,
#  'poetisk': 13327,
#  'stemning': 16764,
#  'nar': 11741,
#  'har': 7708,
#  'vendt': 18732,
#  'sidste': 16025,
#  'hendes': 7919,
#  'boger': 2116,
#  'endnu': 5613,
#  'gang': 7017,
#  'formar': 6766,
#  'tage': 17287,
#  'med': 10909,
#  'ud': 18287,
#  'pa': 12593,
#  'sproglig': 16626,
#  'rejse': 14547,
#  'af': 475,
#  'tolkninger': 17879,
#  'lyrik': 10541,
#  'vil': 18870,
#  'flere': 6603,
#  'ord': 12429,
#  'trods': 18141,
#  'skrivestilen': 16193,
#  'var': 18673,
#  'ikke': 8351,
#  'oppe': 12396,
#  'kore': 9728,
#  'selve': 15638,
#  'handlingen': 7675,
#  'den': 4387,
#  'er': 5761,
#  'god': 7307,
#  'spaendende': 16491,
#  'man': 10670,
#  'nysgerrig': 12170,
#  'igennem': 8330,
#  'bogen': 2115,
#  'men': 11023,
#  'fanget': 6273,
#  'spillet': 16562,
#  'som': 16405,
#  'anden': 850,
#  'bog': 2114,
#  'far': 6294,
#  'afsluttet': 498,
#  'det': 4522,
#  'egentlig': 5356,
#  'bare': 1606,
#  'mellemrejse': 10969,
#  'hvilket': 8259,
#  'fint': 6530,
#  'nok': 12013,
#  'savnede': 15324,
#  'lidt': 10151,
#  'mere': 11134,
#  'hvad': 8256,
#  'kan': 9360,
#  'helt': 7913,
#  'uddybe': 18290,
#  'der': 4428,
#  'manglede': 10688,
#  'anderledes': 853,
#  'handling': 7674,
#  'maske': 10808,
#  'alt': 723,
#  'afsides': 497,
#  'provins': 13873,
#  'arbejdslejr': 1102,
#  'beskidte': 1869,
#  'haender': 7620,
#  'traet': 17980,
#  'krop': 9754,
#  'plagede': 13227,
#  'tanker': 17350,
#  'skyldes': 16200,
#  'ky': 9784,
#  'vaek': 18630,
#  'finde': 6504,
#  'ham': 7656,
#  'maerkeligt': 10579,
#  'fravaer': 6846,
#  'foles': 6684,
#  'naervaer': 11705,
#  'et': 5921,
#  'savn': 15323,
#  'altomfattende': 742,
#  'hvis': 8260,
#  'forsvandt': 6780,
#  'ville': 18877,
#  'vende': 18728,
#  'om': 12336,
#  'min': 11264,
#  'forbloffelse': 6721,
#  'opdage': 12371,
#  'vaerelset': 18633,
#  'alligevel': 694,
#  'tomt': 17890,
#  'selv': 15636,
#  'lige': 10168,
#  'mindste': 11275,
#  'eller': 5462,
#  'andet': 855,
#  'end': 5597,
#  'citat': 3085,
#  '14': 38,
#  'dog': 4959,
#  'stadig': 16667,
#  'serien': 15751,
#  'gar': 7032,
#  'rigtig': 14915,
#  'retning': 14791,
#  'ojne': 12294,
#  'spaendt': 16492,
#  'sker': 16166,
#  'sjaeldent': 16153,
#  'tager': 17288,
#  'parti': 12736,
#  'beslutter': 1870,
#  'hvilken': 8258,
#  'fyr': 6981,
#  'hovedpersonen': 8171,
#  'skal': 16158,
#  'vaelge': 18631,
#  'splittet': 16585,
#  'mellem': 10968,
#  'xander': 19486,
#  'jo': 9183,
#  'dem': 4353,
#  'begge': 1727,
#  'hvem': 8257,
#  'vaelger': 18632,
#  'mon': 11440,
#  'sidst': 16024,
#  'comes': 3308,
#  'circle': 3072,
#  'great': 7437,
#  'human': 8216,
#  'nature': 11779,
#  'gets': 7183,
#  'jaegar': 9057,
#  'fan': 6263,
#  'octavius': 12246,
#  'growing': 7511,
#  'wait': 19023,
#  'hand': 7663,
#  'reread': 14693,
#  'july': 9274,
#  '2014': 91,
#  'march': 10734,
#  '2016': 93,
#  'audiobook': 1366,
#  'think': 17683,
#  'time': 17786,
#  'loved': 10434,
#  'high': 7975,
#  'school': 15400,
#  'year': 19534,
#  'picked': 13150,
#  'books': 2162,
#  'actually': 352,
#  'fell': 6411,
#  'seriously': 15759,
#  'connected': 3520,
#  'course': 3767,
#  'people': 12948,
#  'opinions': 12387,
#  'different': 4666,
#  'depth': 4426,
#  'girl': 7238,
#  'feels': 6400,
#  'confused': 3507,
#  'life': 10162,
#  'suddenly': 16999,
#  'living': 10276,
#  'father': 6330,
#  'new': 11906,
#  'family': 6261,
#  'mysterious': 11674,
#  'turns': 18232,
#  'upside': 18578,
#  'eventually': 5967,
#  'secrets': 15531,
#  'spill': 16561,
#  'recommend': 14408,
#  'sister': 16129,
#  'probably': 13722,
#  'little': 10268,
#  'vampire': 18665,
#  'drama': 5066,
#  'wasn': 19089,
#  'kid': 9583,
#  'slap': 16212,
#  'face': 6185,
#  'know': 9687,
#  'happen': 7698,
#  'nonetheless': 12022,
#  'favorite': 6353,
#  'wouldn': 19425,
#  'searched': 15492,
#  'completed': 3397,
#  'defo': 4282,
#  'kids': 9589,
#  'old': 12308,
#  'precious': 13533,
#  'went': 19181,
#  'entirely': 5696,
#  'sure': 17112,
#  'totally': 17935,
#  'wrong': 19454,
#  'awesome': 1483,
#  'narrate': 11748,
#  'kat': 9389,
#  'mary': 10791,
#  'lillia': 10195,
#  'fantastic': 6286,
#  'strong': 16892,
#  'perfect': 12989,
#  'revenge': 14816,
#  'taking': 17308,
#  'principles': 13699,
#  'stays': 16737,
#  'interesting': 8840,
#  'intriguing': 8893,
#  'minute': 11297,
#  'reading': 14295,
#  'mystery': 11676,
#  'fans': 6280,
#  'need': 11818,
#  'dy': 5223,
#  'spoiler': 16590,
#  'alert': 640,
#  'deciding': 4226,
#  'rating': 14245,
#  'solid': 16388,
#  'conclusion': 3462,
#  'remnant': 14623,
#  'chronicles': 3029,
#  'sequel': 15733,
#  'character': 2881,
#  'development': 4560,
#  'world': 19405,
#  'building': 2404,
#  'apparent': 1040,
#  'highlights': 7980,
#  'novel': 12094,
#  'religious': 14584,
#  'texts': 17616,
#  'weaved': 19142,
#  'final': 6495,
#  'lia': 10122,
#  'undertakes': 18395,
#  'role': 15013,
#  'queen': 14060,
#  'doing': 4962,
#  'immersed': 8421,
#  'politics': 13363,
#  'kingdom': 9623,
#  'morrighan': 11501,
#  'strategies': 16858,
#  'war': 19059,
#  'prep': 13598,
#  'battle': 1653,
#  'komizar': 9706,
#  'able': 225,
#  'return': 14798,
#  'right': 14910,
#  'parents': 12718,
#  'powerful': 13503,
#  'leader': 9947,
#  'sadly': 15197,
#  'issues': 9010,
#  'pacing': 12597,
#  'length': 10045,
#  'moments': 11438,
#  'added': 369,
#  'drag': 5055,
#  'wonderful': 19376,
#  'darkness': 4122,
#  'dragged': 5056,
#  'suffered': 17003,
#  'bc': 1667,
#  'lines': 10227,
#  'terms': 17562,
#  'add': 368,
#  'forced': 6723,
#  'extended': 6142,
#  'lengths': 10046,
#  'prepping': 13607,
#  'outpost': 12529,
#  'makes': 10639,
#  'sense': 15688,
#  'withe': 19331,
#  'perfectly': 12995,
#  'fine': 6510,
#  'returns': 14801,
#  'rest': 14757,
#  'palace': 12642,
#  'personally': 13056,
#  'wise': 19310,
#  'rafe': 14159,
#  'feel': 6397,
#  'kaden': 9318,
#  'pauline': 12831,
#  'liking': 10190,
#  'relationship': 14561,
#  'lot': 10419,
#  'started': 16710,
#  'considering': 3563,
#  'regardless': 14508,
#  'continuing': 3623,
#  'fast': 6321,
#  'paced': 12596,
#  'clue': 3203,
#  'uncertainty': 18348,
#  'came': 2566,
#  'visit': 18902,
#  'venda': 18727,
#  'overall': 12547,
#  'joining': 9205,
#  'adventure': 461,
#  'voice': 18937,
#  'belongs': 1788,
#  'finding': 6508,
#  'happy': 7707,
#  'worried': 19410,
#  'points': 13339,
#  'sad': 15191,
#  'extremely': 6161,
#  'worth': 19419,
#  'buy': 2476,
#  'wish': 19314,
#  'coming': 3320,
#  'today': 17859,
#  'got': 7356,
#  'exchange': 6029,
#  'honest': 8092,
#  'review': 14820,
#  'interested': 8838,
#  'title': 17834,
#  'aversion': 1447,
#  'averted': 1448,
#  'decided': 4222,
#  'try': 18187,
#  'thinking': 17684,
#  'maybe': 10869,
#  'paranormal': 12697,
#  'fantasy': 6293,
#  'im': 8384,
#  'gladly': 7262,
#  'sci': 15417,
#  'fi': 6447,
#  'gemma': 7108,
#  'talent': 17313,
#  'unusual': 18543,
#  'unique': 18465,
#  'heard': 7833,
#  'kenechi': 9492,
#  'job': 9185,
#  'creating': 3829,
#  'power': 13502,
#  'russ': 15149,
#  'cute': 4008,
#  'puppy': 13964,
#  'couple': 3762,
#  'turned': 18227,
#  'fate': 6327,
#  'does': 4956,
#  'easily': 5266,
#  'finish': 6517,
#  'wonder': 19374,
#  'gonna': 7331,
#  'short': 15949,
#  '133': 33,
#  'pages': 12616,
#  'author': 1410,
#  'finished': 6518,
#  'ugh': 18293,
#  'relation': 14560,
#  'touching': 17942,
#  'complicated': 3409,
#  'secret': 15526,
#  'revealed': 14809,
#  'simple': 16091,
#  'thought': 17700,
#  'personality': 13055,
#  'naive': 11719,
#  'trust': 18174,
#  'believe': 1771,
#  'word': 19392,
#  'said': 15213,
#  'later': 9897,
#  'learns': 9971,
#  'ability': 221,
#  'did': 4635,
#  'enjoy': 5646,
#  'fourth': 6810,
#  'giver': 7255,
#  'quartet': 14043,
#  'follows': 6699,
#  'main': 10619,
#  'progresses': 13772,
#  'starts': 16716,
#  'pull': 13937,
#  'pieces': 13163,
#  'developed': 4558,
#  'earlier': 5249,
#  'readable': 14286,
#  'self': 15622,
#  'contained': 3594,
#  'borrowed': 2190,
#  'library': 10137,
#  'availability': 1432,
#  'followed': 6696,
#  'finally': 6499,
#  'marginally': 10745,
#  'sequence': 15735,
#  'reads': 14299,
#  'lois': 10359,
#  'lowry': 10448,
#  'develops': 4562,
#  'societies': 16355,
#  'remote': 14626,
#  'river': 14976,
#  'aware': 1477,
#  'vague': 18637,
#  'crossover': 3903,
#  'society': 16356,
#  'functions': 6951,
#  'rules': 15123,
#  'customs': 4006,
#  'allow': 700,
#  'comparisons': 3365,
#  'written': 19451,
#  'difficult': 4672,
#  'looking': 10388,
#  'escape': 5827,
#  'daily': 4051,
#  'buku': 2411,
#  'remaja': 14603,
#  'tapi': 17365,
#  'filosofis': 6491,
#  'page': 12613,
#  'turner': 18228,
#  'memaksa': 10983,
#  'kita': 9642,
#  'membacanya': 10989,
#  'terus': 17588,
#  'sampai': 15250,
#  'habis': 7589,
#  'karakternya': 9376,
#  'hidup': 7968,
#  'settingnya': 15787,
#  'terasa': 17521,
#  'nyata': 12161,
#  'membuat': 10999,
#  'pembaca': 12894,
#  'juga': 9255,
#  'ingin': 8666,
#  'mengunjunginya': 11074,
#  'plotnya': 13286,
#  'apik': 1011,
#  'banyak': 1601,
#  'diksi': 4697,
#  'yang': 19519,
#  'membawa': 10993,
#  'kpd': 9739,
#  'pengetahuan': 12914,
#  'baru': 1626,
#  'gaya': 7065,
#  'bertuturnya': 1862,
#  'sebuah': 15515,
#  'kisah': 9636,
#  'sedih': 15544,
#  'diceritakan': 4626,
#  'dalam': 4059,
#  'humor': 8226,
#  'sarkasme': 15291,
#  'indah': 8564,
#  'dan': 4079,
#  'masih': 10805,
#  'berhasil': 1832,
#  'menitikkan': 11078,
#  'air': 577,
#  'mata': 10827,
#  'saya': 15332,
#  'kematian': 9481,
#  'selalu': 15606,
#  'menjadi': 11079,
#  'tema': 17467,
#  'mudah': 11582,
#  'menyentuh': 11114,
#  'rainbow': 14183,
#  'rowell': 15090,
#  'discovered': 4797,
#  '2015': 92,
#  'works': 19402,
#  've': 18692,
#  'striking': 16884,
#  'carry': 2704,
#  'exception': 6019,
#  'prose': 13823,
#  'falls': 6245,
#  'imaginative': 8394,
#  'ways': 19116,
#  'things': 17681,
#  'example': 6008,
#  'dream': 5092,
#  'consumed': 3587,
#  'inside': 8728,
#  'cigarette': 3057,
#  'burn': 2444,
#  'eating': 5275,
#  'piece': 13162,
#  'paper': 12679,
#  'description': 4451,
#  'mind': 11268,
#  'relationships': 14562,
#  'catch': 2746,
#  'personal': 13051,
#  'interpretation': 8857,
#  'imagines': 8398,
#  'simon': 16086,
#  'snow': 16333,
#  'fiction': 6456,
#  'leslie': 10066,
#  'wrote': 19457,
#  'original': 12451,
#  'cath': 2752,
#  'fangirl': 6274,
#  'fanfiction': 6271,
#  'fictional': 6457,
#  'super': 17069,
#  'meta': 11178,
#  'stories': 16833,
#  'parallels': 12692,
#  'harry': 7741,
#  'potter': 13480,
#  'fairly': 6228,
#  'certain': 2842,
#  'intentional': 8813,
#  'referenced': 14470,
#  'making': 10643,
#  'entity': 5698,
#  'proving': 13872,
#  'isn': 9000,
#  'avoidance': 1456,
#  'copyright': 3691,
#  'infringement': 8651,
#  'addicting': 372,
#  'grappling': 7420,
#  'shame': 15841,
#  'pride': 13671,
#  'writing': 19449,
#  'fitting': 6555,
#  'years': 19537,
#  'follow': 6695,
#  'suit': 17026,
#  'flawed': 6594,
#  'unlike': 18487,
#  'parodies': 12727,
#  'represent': 14672,
#  'hp': 8176,
#  'stand': 16683,
#  'vibrancy': 18827,
#  'easy': 5272,
#  'draco': 5051,
#  'forget': 6748,
#  'verse': 18796,
#  'completely': 3398,
#  'lost': 10418,
#  'fact': 6198,
#  'refreshing': 14493,
#  'lose': 10410,
#  'stigma': 16800,
#  'realize': 14324,
#  'build': 2403,
#  'pre': 13526,
#  'existing': 6066,
#  'cultural': 3965,
#  'knowledge': 9689,
#  'magic': 10591,
#  'british': 2327,
#  'saving': 15319,
#  'don': 4981,
#  'crazy': 3821,
#  'antics': 970,
#  'pals': 12653,
#  'experienced': 6088,
#  'flashbacks': 6586,
#  'assumed': 1272,
#  'understand': 18387,
#  'magickal': 10596,
#  'creatures': 3838,
#  'evil': 5983,
#  'clear': 3146,
#  'cut': 4007,
#  'prophesy': 13808,
#  'blindly': 2036,
#  'adjust': 408,
#  'terminology': 17560,
#  'normals': 12048,
#  'instance': 8766,
#  'political': 13359,
#  'brilliance': 2317,
#  'means': 10901,
#  'focus': 6672,
#  'important': 8468,
#  'stuff': 16918,
#  'resolution': 14728,
#  'struggled': 16902,
#  'saw': 15327,
#  'familiarity': 6258,
#  'naturally': 11776,
#  'critical': 3885,
#  'pov': 13490,
#  'baz': 1665,
#  'brilliant': 2318,
#  'penny': 12924,
#  'member': 10995,
#  'team': 17416,
#  'speaking': 16513,
#  'chapters': 2880,
#  'changed': 2864,
#  'perspectives': 13067,
#  'set': 15779,
#  'beginning': 1732,
#  'distracting': 4884,
#  'cadence': 2508,
#  'similar': 16079,
#  'monologue': 11457,
#  'lovely': 10438,
#  'glad': 7260,
#  'slash': 16214,
#  'miss': 11341,
#  'worry': 19413,
#  'concept': 3448,
#  'sort': 16463,
#  'sophomore': 16437,
#  'slump': 16264,
#  'long': 10373,
#  'boring': 2183,
#  'hearing': 7834,
#  'thoughts': 17703,
#  'pretty': 13651,
#  'worn': 19409,
#  '2nd': 117,
#  'decent': 4215,
#  '3rd': 130,
#  'wow': 19430,
#  'wonderfully': 19377,
#  'nostalgic': 12059,
#  'dimple': 4718,
#  'doesn': 4957,
#  'want': 19055,
#  'married': 10774,
#  'shes': 15896,
#  '18': 61,
#  'wants': 19058,
#  'education': 5328,
#  'brains': 2246,
#  'doesnt': 4958,
#  'ask': 1228,
#  'traditionally': 17976,
#  'indian': 8574,
#  'mother': 11515,
#  'arranged': 1170,
#  'marriage': 10772,
#  'daughter': 4148,
#  'sets': 15785,
#  'enter': 5680,
#  'rishi': 14952,
#  'half': 7642,
#  'approx': 1081,
#  'tradtional': 17978,
#  'exclusion': 6037,
#  'yes': 19547,
#  'dealt': 4182,
#  'choppiness': 3006,
#  'discordant': 4792,
#  'bursting': 2451,
#  'narrative': 11753,
#  'uncomfortably': 18353,
#  'instead': 8771,
#  'letting': 10078,
#  'sit': 16131,
#  'emotions': 5529,
#  'thats': 17635,
#  'biggest': 1930,
#  'issue': 9009,
#  'kinda': 9613,
#  'real': 14303,
#  'suppose': 17101,
#  'reality': 14321,
#  'pushed': 13988,
#  'favour': 6357,
#  'having': 7787,
#  'sweetest': 17204,
#  'happily': 7705,
#  'patient': 12816,
#  'listened': 10248,
#  'doubt': 5020,
#  'bound': 2208,
#  'form': 6762,
#  'gems': 7109,
#  'pace': 12595,
#  'offer': 12270,
#  'respect': 14742,
#  'oddest': 12255,
#  'tiger': 17777,
#  'quest': 14080,
#  'section': 15532,
#  'contemporary': 3603,
#  'romance': 15026,
#  'kelsey': 9473,
#  'dates': 4142,
#  'guys': 7573,
#  'business': 2458,
#  'ren': 14630,
#  'pointless': 13337,
#  'unnecessary': 18497,
#  'mythology': 11687,
#  'attention': 1340,
#  'imagination': 8393,
#  'saves': 15318,
#  'normally': 12046,
#  'young': 19570,
#  'adult': 450,
#  'simplistic': 16096,
#  'poorly': 13382,
#  'vaguely': 18638,
#  'action': 336,
#  'mildly': 11247,
#  'entertaining': 5685,
#  'highly': 7981,
#  'kept': 9506,
#  'titles': 17835,
#  'look': 10386,
#  'listen': 10247,
#  'friend': 6880,
#  'cd': 2780,
#  'doodling': 4988,
#  'working': 19401,
#  'jigsaw': 9170,
#  'puzzles': 13999,
#  'ordered': 12431,
#  'specials': 16519,
#  'indication': 8575,
#  'fururistic': 6965,
#  'traditional': 17975,
#  'teen': 17438,
#  'turn': 18226,
#  '16': 48,
#  'undergo': 18375,
#  'major': 10627,
#  'cosmetic': 3727,
#  'surgery': 17119,
#  'uglies': 18295,
#  'tally': 17324,
#  'youngblood': 19571,
#  'intrepid': 8885,
#  'heroine': 7938,
#  'counting': 3757,
#  'days': 4166,
#  'makeover': 10638,
#  'prettytown': 13653,
#  'paris': 12720,
#  'party': 12760,
#  'plans': 13242,
#  'halted': 7655,
#  'shay': 15868,
#  'run': 15130,
#  'away': 1479,
#  'smoke': 16299,
#  'charged': 2890,
#  'staying': 16736,
#  'ugly': 18296,
#  'forever': 6742,
#  'contrived': 3641,
#  'pardonable': 12704,
#  'travel': 18055,
#  'based': 1630,
#  'confusing': 3509,
#  'lauren': 9914,
#  'james': 9072,
#  'crafted': 3798,
#  'destiny': 4511,
#  'spanning': 16500,
#  'generations': 7121,
#  'multiple': 11599,
#  'periods': 13012,
#  'structure': 16899,
#  'used': 18594,
#  'giving': 7257,
#  'snippets': 16325,
#  'lives': 10274,
#  'notes': 12072,
#  'emails': 5482,
#  'nice': 11950,
#  'answers': 945,
#  'ongoing': 12352,
#  'questions': 14088,
#  'wrapped': 19435,
#  'following': 6698,
#  'clove': 3199,
#  'katherine': 9400,
#  'mathew': 10842,
#  'tries': 18114,
#  'figure': 6476,
#  'happened': 7699,
#  'save': 15315,
#  'hasn': 7751,
#  'met': 11177,
#  'trying': 18188,
#  'disappeared': 4769,
#  'scattered': 15361,
#  'history': 8021,
#  'recurring': 14441,
#  'keeps': 9444,
#  'meeting': 10925,
#  'quote': 14125,
#  'cover': 3776,
#  'solve': 16402,
#  'past': 12799,
#  'future': 6972,
#  'wins': 19298,
#  'lgbt': 10111,
#  'protagonist': 13836,
#  'especially': 5858,
#  'defined': 4268,
#  'sexuality': 15809,
#  'gay': 7064,
#  'multifaceted': 11598,
#  'knows': 9691,
#  'basically': 1634,
#  'big': 1928,
#  'deal': 4179,
#  'favourites': 6359,
#  'plenty': 13277,
#  'mistakes': 11352,
#  'place': 13221,
#  'root': 15055,
#  'teenager': 17441,
#  'overreacts': 12567,
#  'mix': 11372,
#  'person': 13041,
#  'won': 19373,
#  'deny': 4403,
#  'help': 7906,
#  'come': 3302,
#  'slip': 16242,
#  'created': 3827,
#  'twists': 18259,
#  'second': 15518,
#  'installment': 8762,
#  'infernal': 8624,
#  'devices': 4566,
#  'forward': 6793,
#  'soon': 16425,
#  'tessa': 17598,
#  'independent': 8569,
#  'funny': 6958,
#  'clary': 3118,
#  'mortal': 11506,
#  'instrument': 8777,
#  'ya': 19504,
#  'impressed': 8482,
#  'dystopian': 5236,
#  'live': 10270,
#  'consumerist': 3588,
#  'obsessed': 12208,
#  'beauty': 1694,
#  'fixated': 6558,
#  'unrealistic': 18513,
#  'unhealthy': 18444,
#  'ideal': 8309,
#  'cool': 3677,
#  'minor': 11292,
#  'spoilers': 16593,
#  ...}

# %%
# *loss* & tolerance (asymptotic)
# scikit learn should have a way to look at it
# monitor
# might get weights for each column, look at this, look at vocabulary_

# %%
import json
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
import datetime

# %%
# load the reviews from the JSON file into a Pandas DataFrame
reviews = []
with open('goodreads_reviews_young_adult.json', 'r') as f:
    for line in f:
        review = json.loads(line)
        reviews.append((review['review_text'], review['rating']))
df = pd.DataFrame(reviews, columns=['text', 'rating'])

# define a function to map ratings to sentiment labels
def map_rating_to_sentiment(rating):
    if rating >= 3:
        return 'positive'
    else:
        return 'negative'

# %%
# map the ratings to sentiment labels
df['sentiment'] = df['rating'].apply(map_rating_to_sentiment)

# split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(df['text'], df['sentiment'], test_size=0.2, random_state=42)

# %%
# %timeit
# vectorize the text data using a bag-of-words model
vectorizer = CountVectorizer(stop_words='english')
X_train_vec = vectorizer.fit_transform(X_train)
X_test_vec = vectorizer.transform(X_test)

# %%
# train an SVM classifier on the training data
clf = SVC(kernel='linear', C=1.0, random_state=42, tol = 1)
clf.fit(X_train_vec, y_train)


# tolerence if increase, then it woukd take shorter, try tolerence at 1 to check if it works at all
# errors might continuously occilate, eliminate the possibility, but this should work in this case!

# evaluate the performance of the classifier on the testing data
accuracy = clf.score(X_test_vec, y_test)
print("Accuracy of the classifier on the testing set: {:.2f}%".format(accuracy * 100))

# %%
import json
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
import datetime

# start time
start_time = datetime.datetime.now()

# load the reviews from the JSON file into a Pandas DataFrame
reviews = []
with open('goodreads_reviews_young_adult.json', 'r') as f:
    for line in f:
        review = json.loads(line)
        reviews.append((review['review_text'], review['rating']))
df = pd.DataFrame(reviews, columns=['text', 'rating'])

# define a function to map ratings to sentiment labels
def map_rating_to_sentiment(rating):
    if rating >= 3:
        return 'positive'
    else:
        return 'negative'

# map the ratings to sentiment labels
df['sentiment'] = df['rating'].apply(map_rating_to_sentiment)

# split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(df['text'], df['sentiment'], test_size=0.2, random_state=42)

# vectorize the text data using a tf-idf model
vectorizer = TfidfVectorizer(stop_words='english')
X_train_vec = vectorizer.fit_transform(X_train)
X_test_vec = vectorizer.transform(X_test)

# train an SVM classifier on the training data
clf = SVC(kernel='linear', C=1.0, random_state=42)
clf.fit(X_train_vec, y_train)

# evaluate the performance of the classifier on the testing data
accuracy = clf.score(X_test_vec, y_test)
print("Accuracy of the classifier on the testing set: {:.2f}%".format(accuracy * 100))

# end time
end_time = datetime.datetime.now()

# total time
delta_time = end_time - start_time
print(f"Elapsed time: {delta_time.total_seconds()} seconds")
